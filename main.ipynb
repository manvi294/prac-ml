# %%
# welcome to iris dataset analysis

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import re
import matplotlib.pyplot
from scipy.stats import norm

# %%
# loading dataset
head_row = ["sepal_length", "sepal_width","petal_length", "petal_width", "class_name"]
data = pd.read_csv('D:/ml/vir/prac-ml/iris.data', header=None, names=head_row)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class_name
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# data understanding and identification fo data types
print("Sepal Length")
print(data["sepal_length"].unique())
print(data["sepal_length"].dtype)
print("Sepal Width")
print(data["sepal_width"].unique())
print(data["sepal_width"].dtype)
print("Petal Length")
print(data["petal_length"].unique())
print(data["petal_length"].dtype)
print("Petal Width")
print(data["petal_width"].unique())
print(data["petal_width"].dtype)
print("Class")
print(data["class_name"].unique())
print(data["class_name"].dtype)
print(data.shape)
# Out:
# Sepal Length
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
# float64
# Sepal Width
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
# float64
# Petal Length
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
# float64
# Petal Width
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
# float64
# Class
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# object
# (150, 5)

# %%
# data description
# print(data['class_name'].describe())
# print(data['petal_length'].describe())
# print(data['petal_width'].describe())
# print(data['sepal_length'].describe())
# print(data['sepal_width'].describe())
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# data visualizations: univariate
data_numeric= [data['sepal_length'], data['sepal_width'], data['petal_length'], data['petal_width'] ]
matplotlib.pyplot.boxplot(data_numeric, notch='True', patch_artist=True, widths=None, vert=0)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a9dd5f3cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a9df6132b0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1a9dd5f3910>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a9df613850>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a9df613b20>,
# ...
#  'means': []}

# %%
# bivariate analysis
corrmat = data.corr()
f, ax = matplotlib.pyplot.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
# inference: sepal length and width can be used
# Out:
# <AxesSubplot:>

# %%
# distribution analysis :bivariate

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

#fig, ax =matplotlib.pyplot.subplots(1,2)
sns.lmplot('sepal_length', 'sepal_width', data=data, hue='class_name', fit_reg=False)
sns.lmplot('petal_length', 'petal_width', data=data, hue='class_name', fit_reg=False)
#fig.show()

# %%
# perform univariate analysis: t test, anova, etc

# %%
#missing values:
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class_name      0
# dtype: int64

# %%
# remove outliers
# boxplot, iqr, zscore

# %%
# encoding
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
data['class_name'] = ord_enc.fit_transform(data[['class_name']])
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class_name
# 0             5.1          3.5           1.4          0.2         0.0
# 1             4.9          3.0           1.4          0.2         0.0
# 2             4.7          3.2           1.3          0.2         0.0
# 3             4.6          3.1           1.5          0.2         0.0
# 4             5.0          3.6           1.4          0.2         0.0
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3         2.0
# 146           6.3          2.5           5.0          1.9         2.0
# 147           6.5          3.0           5.2          2.0         2.0
# 148           6.2          3.4           5.4          2.3         2.0
# 149           5.9          3.0           5.1          1.8         2.0
#
# [150 rows x 5 columns]

# %%
# feature scaling
def scalef(aray) :
    mini = min(aray)
    maxi = max(aray)
    for x in range(0,len(aray)) :
        aray[x] = (aray[x] - mini)/(maxi-mini)

        
scalef(data['sepal_length'])
scalef(data['sepal_width'])
scalef(data['petal_length'])
scalef(data['petal_width'])
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class_name
# 0        0.222222     0.625000      0.067797     0.041667         0.0
# 1        0.166667     0.416667      0.067797     0.041667         0.0
# 2        0.111111     0.500000      0.050847     0.041667         0.0
# 3        0.083333     0.458333      0.084746     0.041667         0.0
# 4        0.194444     0.666667      0.067797     0.041667         0.0
# ..            ...          ...           ...          ...         ...
# 145      0.666667     0.416667      0.711864     0.916667         2.0
# 146      0.555556     0.208333      0.677966     0.750000         2.0
# 147      0.611111     0.416667      0.711864     0.791667         2.0
# 148      0.527778     0.583333      0.745763     0.916667         2.0
# 149      0.444444     0.416667      0.694915     0.708333         2.0
#
# [150 rows x 5 columns]

# %%
# # feature z score normalization: standardization

# def normalize(aray) :
#     mean_aray = sum(aray)/len(aray)
#     v_sum=0
#     for x in range(0,len(aray)) :
#         v_sum += (aray[x]-mean_aray)**2
#         aray[x] = aray[x]-mean_aray
#     var_aray = (v_sum/len(aray))**0.5
#     for aray[x] in aray :
#         aray[x] = aray[x]/var_aray
    
# normalize(data['sepal_length'])
# normalize(data['sepal_width'])
# normalize(data['petal_length'])
# normalize(data['petal_width'])
# data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class_name
# 0       -0.206481     0.185833     -0.399774    -0.416111         0.0
# 1       -0.262037    -0.022500     -0.399774    -0.416111         0.0
# 2       -0.317593     0.060833     -0.416723    -0.416111         0.0
# 3       -0.345370     0.019167     -0.382825    -0.416111         0.0
# 4       -0.234259     0.227500     -0.399774    -0.416111         0.0
# ..            ...          ...           ...          ...         ...
# 145      0.237963    -0.022500      0.244294     0.458889         2.0
# 146      0.126852    -0.230833      0.210395     0.292222         2.0
# 147      0.182407    -0.022500      0.244294     0.333889         2.0
# 148      0.099074     0.144167      0.278192     0.458889         2.0
# 149      1.885124     4.446570      3.131480     4.568809         2.0
#
# [150 rows x 5 columns]
